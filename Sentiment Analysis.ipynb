# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('web_scrapping.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0     Customer Name       Review Rating  \
# 0           0         Aman More  4.0 out of 5 stars
# 1           1  Abhishek Agarwal  3.0 out of 5 stars
# 2           2          Kiran KS  4.0 out of 5 stars
# 3           3            Nikhil  5.0 out of 5 stars
# 4           4       Deblina Roy  2.0 out of 5 stars
#
#                        Review Title  \
# 0              A good daily driver.
# 1                    Bad bad camera
# 2  The original segment of One Plus
# 3           *Read before you buy!!*
# 4                     Disappointing
#
#                                       Review Content  \
# 0    Pros:1) Clean and bloatfree OxygenOS, which ...
# 1    It's not very often I leave a critical revie...
# 2    Battery usage update: Drains faster than oth...
# 3    Yea..pre-ordered on 28 July, got it on 4 Aug...
# 4    Heavily disappointed. So much of hype and th...
#
#                                         Product Name
# 0  OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB S...
# 1  OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB S...
# 2  OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB S...
# 3  OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB S...
# 4  OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB S...

# %% [markdown]
# ### Removing upper case letters

# %%
df['Review Content'] = df['Review Content'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['Review Content'].head()
# Out:
# 0    pros:1) clean and bloatfree oxygenos, which ru...
# 1    it's not very often i leave a critical review ...
# 2    battery usage update: drains faster than other...
# 3    yea..pre-ordered on 28 july, got it on 4 augus...
# 4    heavily disappointed. so much of hype and the ...
# Name: Review Content, dtype: object

# %% [markdown]
# ### Removing punctuations

# %%
df['Review Content'] = df['Review Content'].str.replace('[^\w\s]','')
df['Review Content'].head()
# Out:
# 0    pros1 clean and bloatfree oxygenos which runs ...
# 1    its not very often i leave a critical review f...
# 2    battery usage update drains faster than other ...
# 3    yeapreordered on 28 july got it on 4 august pa...
# 4    heavily disappointed so much of hype and the c...
# Name: Review Content, dtype: object

# %% [markdown]
# ### Removal of stopwords

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
df['Review Content'] = df['Review Content'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['Review Content'].sample(10)
# Out:
# 57    giving review spending 20 days phone retail us...
# 38    totally impressed built looks 13k thought gett...
# 29    writing review using phone 7 days believe real...
# 87                                   super mobile phone
# 8     front camera bad low light photo also bad need...
# 9     prosmooth os lags allamoled screen good qualit...
# 30      dont buy 10 to15 mins gaming phone lagging much
# 28    obviously might done extensive research watche...
# 86    expect price everything perfecta beautiful mob...
# 68    opinion dont think much phone get attaching ni...
# Name: Review Content, dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0     Customer Name       Review Rating  \
# 0           0         Aman More  4.0 out of 5 stars
# 1           1  Abhishek Agarwal  3.0 out of 5 stars
# 2           2          Kiran KS  4.0 out of 5 stars
# 3           3            Nikhil  5.0 out of 5 stars
# 4           4       Deblina Roy  2.0 out of 5 stars
#
#                        Review Title  \
# 0              A good daily driver.
# 1                    Bad bad camera
# 2  The original segment of One Plus
# 3           *Read before you buy!!*
# 4                     Disappointing
#
#                                       Review Content  \
# 0  pros1 clean bloatfree oxygenos runs smooth com...
# 1  often leave critical review product excited ne...
# 2  battery usage update drains faster one plus mo...
# 3  yeapreordered 28 july got 4 august package nic...
# 4  heavily disappointed much hype camera even upt...
#
#                                         Product Name
# 0  OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB S...
# 1  OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB S...
# 2  OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB S...
# 3  OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB S...
# 4  OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB S...

# %% [markdown]
# ### Assigning Polarity Scores

# %%
from textblob import TextBlob

# %%
#Create quick lambda functions to find the polarity
#Polarity is float which lies in the range of [-1,1] where 1 means positive statement and -1 means a negative statement.
df['Review Content']= df['Review Content'].astype(str)
pol = lambda x: TextBlob(x).sentiment.polarity
df['polarity'] = df['Review Content'].apply(pol)
df
# Out:
#     Unnamed: 0      Customer Name       Review Rating  \
# 0            0          Aman More  4.0 out of 5 stars
# 1            1   Abhishek Agarwal  3.0 out of 5 stars
# 2            2           Kiran KS  4.0 out of 5 stars
# 3            3             Nikhil  5.0 out of 5 stars
# 4            4        Deblina Roy  2.0 out of 5 stars
# ..         ...                ...                 ...
# 95          95               Sasa  4.0 out of 5 stars
# 96          96  Krishnakant Nigam  1.0 out of 5 stars
# 97          97           abhishek  5.0 out of 5 stars
# 98          98    DARSHA H JIWANI  5.0 out of 5 stars
# 99          99        MANOJ KUMAR  3.0 out of 5 stars
#
#                         Review Title  \
# 0               A good daily driver.
# 1                     Bad bad camera
# 2   The original segment of One Plus
# 3            *Read before you buy!!*
# 4                      Disappointing
# ..                               ...
# 95                          Oppo A52
# 96                   Heating problem
# 97      Camera and processor is good
# 98                        Nice phone
# 99                         Oppo a 52
#
#                                        Review Content  \
# 0   pros1 clean bloatfree oxygenos runs smooth com...
# 1   often leave critical review product excited ne...
# 2   battery usage update drains faster one plus mo...
# 3   yeapreordered 28 july got 4 august package nic...
# 4   heavily disappointed much hype camera even upt...
# ..                                                ...
# 95  chose mobile others later delivery area go loc...
# 96           heating problem therevery bad experience
# 97                                        nice camera
# 98                                         nice phone
# 99                      phone call recording function
#
#                                          Product Name  polarity
# 0   OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB S...  0.215650
# 1   OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB S...  0.083182
# 2   OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB S...  0.344118
# 3   OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB S...  0.266724
# 4   OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB S...  0.091026
# ..                                                ...       ...
# 95  OPPO A52 (Stream White, 6GB RAM, 128GB Storage...  0.298611
# 96  OPPO A52 (Stream White, 6GB RAM, 128GB Storage... -0.700000
# 97  OPPO A52 (Stream White, 6GB RAM, 128GB Storage...  0.600000
# 98  OPPO A52 (Stream White, 6GB RAM, 128GB Storage...  0.600000
# 99  OPPO A52 (Stream White, 6GB RAM, 128GB Storage...  0.000000
#
# [100 rows x 7 columns]

# %%
df.to_csv('Amazon_reviews_scores.csv', index=False)
